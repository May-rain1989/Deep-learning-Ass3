# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import Huber

# 1. Load data
train_file = "Google_Stock_Price_Train.csv"
test_file = "Google_Stock_Price_Test.csv"

# Load datasets
train_data = pd.read_csv(train_file)
test_data = pd.read_csv(test_file)

# Data preprocessing
features = ['Open', 'High', 'Low', 'Close', 'Volume']
for col in features:
    train_data[col] = train_data[col].replace(',', '', regex=True).astype(float)
    test_data[col] = test_data[col].replace(',', '', regex=True).astype(float)

# Extract features and targets
X_train = train_data[features].values
y_train = train_data[features].values  # Targets include all features
X_test = test_data[features].values
y_test = test_data[features].values

# Split the training set into training and validation sets
train_size = int(len(X_train) * 0.8)
X_train_raw = X_train[:train_size]
y_train_raw = y_train[:train_size]
X_val_raw = X_train[train_size:]
y_val_raw = y_train[train_size:]

print(f"Train raw size: {len(X_train_raw)}, Val raw size: {len(X_val_raw)}, Test raw size: {len(X_test)}")

# Set time window for sequence generation
time_steps = 10

# Normalize data
feature_scaler = MinMaxScaler()
X_train_scaled = feature_scaler.fit_transform(X_train_raw)
X_val_scaled = feature_scaler.transform(X_val_raw)
X_test_scaled = feature_scaler.transform(X_test)

target_scaler = MinMaxScaler()
y_train_scaled = target_scaler.fit_transform(y_train_raw)
y_val_scaled = target_scaler.transform(y_val_raw)
y_test_scaled = target_scaler.transform(y_test)

# 2. Define a function to generate time-series data
def create_time_series(data, labels, time_steps):
    if len(data) <= time_steps:
        raise ValueError(f"Data size ({len(data)}) is too small for time_steps ({time_steps}).")
    X, y = [], []
    for i in range(time_steps, len(data)):
        X.append(data[i-time_steps:i])
        y.append(labels[i])
    return np.array(X), np.array(y)

# Generate time-series data
X_train_seq, y_train_seq = create_time_series(X_train_scaled, y_train_scaled, time_steps)
X_val_seq, y_val_seq = create_time_series(X_val_scaled, y_val_scaled, time_steps)
X_test_seq, y_test_seq = create_time_series(X_test_scaled, y_test_scaled, time_steps)

print(f"Training Set X: {X_train_seq.shape}, Validation Set X: {X_val_seq.shape}, Testing Set X: {X_test_seq.shape}")

# 3. Build the model
model = Sequential([
    GRU(units=50, activation='tanh', return_sequences=True, input_shape=(time_steps, X_train_seq.shape[2])),
    Dropout(0.2),
    GRU(units=50, activation='tanh', return_sequences=False),
    Dropout(0.2),
    Dense(len(features), activation='linear')  # Output layer with linear activation to predict all features
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss=Huber())
model.summary()

# 4. Train the model
history = model.fit(
    X_train_seq, y_train_seq,
    validation_data=(X_val_seq, y_val_seq),
    epochs=100,
    batch_size=32,
    verbose=1
)

# 5. Evaluate and make predictions
test_loss = model.evaluate(X_test_seq, y_test_seq, verbose=1)
print(f"\nTest Loss (Huber): {test_loss}")

# De-normalize predictions
y_pred = model.predict(X_test_seq)
y_pred_actual = target_scaler.inverse_transform(y_pred)
y_test_actual = target_scaler.inverse_transform(y_test_seq)

# 6. Visualize predictions
for i, feature in enumerate(features):
    plt.figure(figsize=(10, 6))
    plt.plot(y_test_actual[:, i], label=f'True {feature}', marker='o')
    plt.plot(y_pred_actual[:, i], label=f'Predicted {feature}', marker='x')
    plt.title(f'Test Set Predictions (De-normalized) - {feature}')
    plt.xlabel('Samples')
    plt.ylabel(feature)
    plt.legend()
    plt.show()

# 7. Visualize training process
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss (Huber)')
plt.legend()
plt.show()

# 8. Visualize error distribution
errors = y_test_actual - y_pred_actual
for i, feature in enumerate(features):
    plt.figure(figsize=(8, 6))
    plt.hist(errors[:, i], bins=10, edgecolor='black')
    plt.title(f'Prediction Errors - {feature}')
    plt.xlabel('Error')
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Train raw size: 1006, Val raw size: 252, Test raw size: 20
# Training Set X: (996, 10, 5), Validation Set X: (242, 10, 5), Testing Set X: (10, 10, 5)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 10, 50)            8550
#
#  dropout (Dropout)           (None, 10, 50)            0
#
#  gru_1 (GRU)                 (None, 50)                15300
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 5)                 255
#
# =================================================================
# Total params: 24105 (94.16 KB)
# Trainable params: 24105 (94.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 32/32 [==============================] - 9s 52ms/step - loss: 0.0203 - val_loss: 0.0132
# Epoch 2/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0050 - val_loss: 0.0029
# Epoch 3/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0040 - val_loss: 0.0016
# Epoch 4/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0036 - val_loss: 0.0016
# Epoch 5/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 0.0013
# Epoch 6/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0030 - val_loss: 0.0012
# Epoch 7/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0030 - val_loss: 0.0014
# Epoch 8/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 9/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0026 - val_loss: 4.7289e-04
# Epoch 10/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0027 - val_loss: 3.7385e-04
# Epoch 11/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0026 - val_loss: 0.0010
# Epoch 12/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0023 - val_loss: 0.0015
# Epoch 13/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0024 - val_loss: 9.3687e-04
# Epoch 14/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0023 - val_loss: 3.5844e-04
# Epoch 15/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0023 - val_loss: 5.8103e-04
# Epoch 16/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0021 - val_loss: 4.3464e-04
# Epoch 17/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0020 - val_loss: 5.5667e-04
# Epoch 18/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0022 - val_loss: 8.8897e-04
# Epoch 19/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0020 - val_loss: 4.7716e-04
# Epoch 20/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0020 - val_loss: 3.7978e-04
# Epoch 21/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0019 - val_loss: 4.8622e-04
# Epoch 22/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0020 - val_loss: 3.6895e-04
# Epoch 23/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0018 - val_loss: 6.0892e-04
# Epoch 24/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 25/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0018 - val_loss: 3.6633e-04
# Epoch 26/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0019 - val_loss: 4.5702e-04
# Epoch 27/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 28/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0018 - val_loss: 8.5753e-04
# Epoch 29/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0017 - val_loss: 4.5738e-04
# Epoch 30/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0016 - val_loss: 3.4491e-04
# Epoch 31/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0016 - val_loss: 3.8747e-04
# Epoch 32/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0016 - val_loss: 4.2920e-04
# Epoch 33/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0017 - val_loss: 4.0519e-04
# Epoch 34/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 5.9276e-04
# Epoch 35/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0016 - val_loss: 5.8363e-04
# Epoch 36/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 3.5661e-04
# Epoch 37/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 3.1592e-04
# Epoch 38/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0015 - val_loss: 8.7562e-04
# Epoch 39/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 5.6811e-04
# Epoch 40/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 3.2137e-04
# Epoch 41/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 3.9263e-04
# Epoch 42/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 4.4404e-04
# Epoch 43/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 4.4484e-04
# Epoch 44/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 4.1169e-04
# Epoch 45/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0014 - val_loss: 2.6511e-04
# Epoch 46/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 2.7423e-04
# Epoch 47/100
# 32/32 [==============================] - 0s 14ms/step - loss: 0.0014 - val_loss: 3.7301e-04
# Epoch 48/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 3.3393e-04
# Epoch 49/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 4.1721e-04
# Epoch 50/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 2.9669e-04
# Epoch 51/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 3.3692e-04
# Epoch 52/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 3.1273e-04
# Epoch 53/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0012 - val_loss: 3.0683e-04
# Epoch 54/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 3.1561e-04
# Epoch 55/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 4.5371e-04
# Epoch 56/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 2.6350e-04
# Epoch 57/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 4.2026e-04
# Epoch 58/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 2.4832e-04
# Epoch 59/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 3.3056e-04
# Epoch 60/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 2.9442e-04
# Epoch 61/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 2.9643e-04
# Epoch 62/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 3.2015e-04
# Epoch 63/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 3.0077e-04
# Epoch 64/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0012 - val_loss: 3.1554e-04
# Epoch 65/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 2.9702e-04
# Epoch 66/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 3.0491e-04
# Epoch 67/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 3.6854e-04
# Epoch 68/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 3.0055e-04
# Epoch 69/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 2.6721e-04
# Epoch 70/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 4.0965e-04
# Epoch 71/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 2.4932e-04
# Epoch 72/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 3.3398e-04
# Epoch 73/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 3.2482e-04
# Epoch 74/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 3.0709e-04
# Epoch 75/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 2.4034e-04
# Epoch 76/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 2.5806e-04
# Epoch 77/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 2.3604e-04
# Epoch 78/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 2.8725e-04
# Epoch 79/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 3.1034e-04
# Epoch 80/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 3.7344e-04
# Epoch 81/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0011 - val_loss: 2.7515e-04
# Epoch 82/100
# 32/32 [==============================] - 0s 14ms/step - loss: 0.0011 - val_loss: 5.8414e-04
# Epoch 83/100
# 32/32 [==============================] - 0s 14ms/step - loss: 0.0011 - val_loss: 5.7031e-04
# Epoch 84/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 2.8476e-04
# Epoch 85/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 3.5372e-04
# Epoch 86/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 4.1621e-04
# Epoch 87/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 2.2485e-04
# Epoch 88/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0011 - val_loss: 5.2075e-04
# Epoch 89/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 3.3596e-04
# Epoch 90/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 3.4025e-04
# Epoch 91/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 2.5656e-04
# Epoch 92/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0010 - val_loss: 2.5090e-04
# Epoch 93/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0011 - val_loss: 3.0021e-04
# Epoch 94/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 4.2179e-04
# Epoch 95/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 2.7285e-04
# Epoch 96/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0010 - val_loss: 3.9003e-04
# Epoch 97/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0010 - val_loss: 2.6223e-04
# Epoch 98/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 2.7690e-04
# Epoch 99/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 4.3959e-04
# Epoch 100/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0010 - val_loss: 2.5129e-04
# 1/1 [==============================] - 0s 36ms/step - loss: 2.7701e-04
#
# Test Loss (Huber): 0.0002770085702650249
# 1/1 [==============================] - 1s 1s/step
